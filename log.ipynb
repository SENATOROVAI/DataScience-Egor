# %%
"""Файл логов."""
# Out:
# 'Файл логов.'

# %% [markdown]
# ### 07/10/24
# Вспоминали школьную математику:
#
# 1. Понятие мнимой единицы
# 2. Кванторы и условные обозначения
# 3. Интервал, полуинтервал, отрезок
# 4. Основные законы алгебры
# 5. Противоположные и обратные числа

# %% [markdown]
# ### 14/10/24
# Проходили пределы:
#
# 1. Понятие последовательности
# 2. Способы задания последовательности (рекуррентный и формула общего члена)
# 3. Ограниченная и неограниченная последовательность
# 4. Сумма, разность и частное последовательностей
# 5. Понятие эпсилон акрестности
# 6. Понятие предела по Коши
# 7. Понятие ограниченной последовательности
# 8. Бесконечно малые и бесконечно большие последовательности
# 9. Свойства сходящихся последовательностей
# 10. Способы нахождения пределов - (деление на старшую степень, умножение на то же число с противоположным знаком)
